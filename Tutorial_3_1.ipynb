# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def mean_filter(image, kernel_size):
    img_array = np.asarray(image)
    
    height,width = img_array.shape
    
    #define the kernel dimensions
    kernel_height,kernel_width = kernel_size
    
    #padding dimensions
    pad_height = kernel_height-1//2
    pad_width = kernel_width -1 //2
    #pad the image array
    
    padded_img= np.pad(img_array, ((pad_height, pad_height), (pad_width, pad_width)))
    
    #create an empty arrayto store the new filtered image
    filtered_img = np.zeros_like(img_array)
    
    #iterate over each pixel in the image
    for x in range(width):
        for y in range(height):
            neighborhood = padded_img[y:y + kernel_height, x:x + kernel_width]
            
            #compute the mean of the neighborhood
            filtered_img[y, x] = np.mean(neighborhood)
    return Image.fromarray(filtered_img)

image_path='./Desktop/images/1.jpg'
original_image = Image.open(image_path).convert('L')

#apply the mean filter
filtered_image = mean_filter(original_image, (3,3))

#ploting original and filtered images using matplotlib
plt.figure(figsize=(12,6))

#original image
plt.subplot(1,2,1)
plt.imshow(original_image,cmap='gray')
plt.title('original image')
plt.axis('off')

#filteredimage
plt.subplot(1,2,2)
plt.imshow(filtered_image, cmap='gray')
plt.title('filtered image')
plt.axis('off')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def apply_filter(image, kernel):
    img_array = np.asarray(image)
    
    height,width = img_array.shape
    
    #define the kernel dimensions
    kernel_height,kernel_width = kernel.shape
    
    #padding dimensions
    pad_height = kernel_height-1//2
    pad_width = kernel_width -1 //2
    #pad the image array
    
    padded_img= np.pad(img_array, ((pad_height, pad_height), (pad_width, pad_width)))
    
    #create an empty arrayto store the new filtered image
    filtered_img = np.zeros_like(img_array)
    
    #iterate over each pixel in the image
    for y in range(height):
        for x in range(width):
            region = padded_img[y:y + kernel_height, x:x + kernel_width]
            
            #apply the filter convolution
            filtered_img[y, x] = np.sum(region * kernel)
    return Image.fromarray(filtered_img.astype(np.uint8))
#define a 3 x3 averaging filter
average_filter = np.ones((3,3)) / 9
#load image
image_path='./Desktop/images/1.jpg'
original_image = Image.open(image_path).convert('L')

#apply the  filter
filtered_image = apply_filter(original_image, average_filter)

#ploting original and filtered images using matplotlib
plt.figure(figsize=(12,6))

#original image
plt.subplot(1,2,1)
plt.imshow(original_image,cmap='gray')
plt.title('original image')
plt.axis('off')

#filteredimage
plt.subplot(1,2,2)
plt.imshow(filtered_image, cmap='gray')
plt.title('filtered image')
plt.axis('off')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def apply_filter(image, kernel):
    #convert image tonumpy array
    img_array = np.asarray(image)
    
    height,width = img_array.shape
    
    #define the kernel dimensions
    kernel_height,kernel_width = kernel.shape
    
    #padding dimensions
    pad_height = kernel_height-1//2
    pad_width = kernel_width -1 //2
    #pad the image array
    
    padded_img= np.pad(img_array, ((pad_height, pad_height), (pad_width, pad_width)))
    
    #create an empty arrayto store the new filtered image
    filtered_img = np.zeros_like(img_array)
    
    #iterate over each pixel in the image
    for y in range(height):
        for x in range(width):
            region = padded_img[y:y + kernel_height, x:x + kernel_width]
            
            #apply the filter convolution
            filtered_img[y, x] = np.sum(region * kernel)
    return Image.fromarray(filtered_img.astype(np.uint8))
#define a 3x3 weighted average filter
weighted_average_filter = np.array([[1,3,5], [3,5,3],[5,3,1]])/29
#load image
image_path='./Desktop/images/1.jpg'
original_image = Image.open(image_path).convert('L')

#apply the  filter
filtered_image = apply_filter(original_image, average_filter)

#ploting original and filtered images using matplotlib
plt.figure(figsize=(12,6))

#original image
plt.subplot(1,2,1)
plt.imshow(original_image,cmap='gray')
plt.title('original image')
plt.axis('off')

#filteredimage
plt.subplot(1,2,2)
plt.imshow(filtered_image, cmap='gray')
plt.title('filtered image')
plt.axis('off')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def apply_filter(image, kernel):
    #convert image tonumpy array
    img_array = np.asarray(image)
    
    height,width = img_array.shape
    
    #define the kernel dimensions
    kernel_height,kernel_width = kernel.shape
    
    #padding dimensions
    pad_height = kernel_height-1//2
    pad_width = kernel_width -1 //2
    #pad the image array
    
    padded_img= np.pad(img_array, ((pad_height, pad_height), (pad_width, pad_width)))
    
    #create an empty arrayto store the new filtered image
    filtered_img = np.zeros_like(img_array)
    
    #iterate over each pixel in the image
    for y in range(height):
        for x in range(width):
            region = padded_img[y:y + kernel_height, x:x + kernel_width]
            
            #apply the filter convolution
            filtered_img[y, x] = np.sum(region * kernel)
    return Image.fromarray(filtered_img.astype(np.uint8))
#define a 3x3 weighted average filter
weighted_average_filter = np.array([[1,3,5], [3,5,3],[5,3,1]])/ 16

#definea 5x5 weighted average filter

#load image
image_path='./Desktop/images/1.jpg'
original_image = Image.open(image_path).convert('L')

#apply the  filter
filtered_image = apply_filter(original_image, average_filter)

#ploting original and filtered images using matplotlib
plt.figure(figsize=(12,6))

#original image
plt.subplot(1,2,1)
plt.imshow(original_image,cmap='gray')
plt.title('original image')
plt.axis('off')

#filteredimage
plt.subplot(1,2,2)
plt.imshow(filtered_image, cmap='gray')
plt.title('filtered image')
plt.axis('off')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def apply_filter(image, kernel):
    #convert image tonumpy array
    img_array = np.asarray(image)
    
    height,width = img_array.shape
    
    #define the kernel dimensions
    kernel_height,kernel_width = kernel.shape
    
    #padding dimensions
    pad_height = kernel_height-1//2
    pad_width = kernel_width -1 //2
    #pad the image array
    
    padded_img= np.pad(img_array, ((pad_height, pad_height), (pad_width, pad_width)))
    
    #create an empty arrayto store the new filtered image
    filtered_img = np.zeros_like(img_array)
    
    #iterate over each pixel in the image
    for y in range(height):
        for x in range(width):
            region = padded_img[y:y + kernel_height, x:x + kernel_width]
            
            #apply the filter convolution
            filtered_img[y, x] = np.sum(region * kernel)
    return Image.fromarray(filtered_img.astype(np.uint8))

#define a laplacian filter kernel
laplacian_kernel = np.array([[0,1,0],[1,-4,1],[0,1,0]])

#load image
image_path='./Desktop/images/1.jpg'
original_image = Image.open(image_path).convert('L')

#apply the  filter
filtered_image = apply_filter(original_image, laplacian_kernel)

#ploting original and filtered images using matplotlib
plt.figure(figsize=(12,6))

#original image
plt.subplot(1,2,1)
plt.imshow(original_image,cmap='gray')
plt.title('original image')
plt.axis('off')

#filteredimage
plt.subplot(1,2,2)
plt.imshow(filtered_image, cmap='gray')
plt.title('filtered image')
plt.axis('off')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import convolve

def gaussian_kernel_1d_horizontal(sigma,length):
    """generate a ID horizontal gaussian kernel"""
    x = np.linspace(-length // 2, length//2, length)
    kernel_1d = np.exp(-(x**2)/(2 * sigma**2))
    return kernel_1d / np.sum(kernel_1d)


def gaussian_kernel_1d_horizontal(sigma,length):
    """generate a ID horizontal gaussian kernel"""
    x = np.linspace(-length // 2, length//2, length)
    kernel_1d = np.exp(-(x**2)/(2 * sigma**2))
    return (kernel_1d / np.sum(kernel_1d)).reshape(-1,1)

#parameters for gausian filtetr
sigma=5.0
kernel_size=25

#generate horizontaland vertical gausian kernels
horizontal_kernel = gaussian_kernel_1d_horizontal(sigma, kernel_size)
vertical_kernel = gaussian_kernel_1d_horizontal(sigma, kernel_size)

#output thekernels
print("Horizontal_gausian kernel:\n",horizontal_kernel )
print("verical_gausian kernel:\n",vertical_kernel )

def apply_filter(image, kernel):
    #determine if the kernel is horizontal or vertical
    if kernel.ndim ==1:
        #for a horizontal kernel,reshape itto (1, kernel_size)
        if kernel.shape[0] == 1:
            kernel = kernel.reshape(1,-1)
        #for a vertical kernel,reshape into a (kernel_size, 1)
        else:
            kernel = kernel.reshape(-1,1)
            
    #apply 2D convolution
    return convolve(image, kernel,mode='constant', cval=0.0)

#generate the equivalent 2D gaussian filter
gaussian_2d = np.outer(horizontal_kernel, vertical_kernel)
   

#load image
image_path='./Desktop/images/1.jpg'
original_image = Image.open(image_path).convert('L')
img_array =np.asarray(original_image)


#apply the 1D filter
filtered_image_1d_horizontal = apply_filter(img_array,horizontal_kernel)
filtered_image_1d_vertical = apply_filter(img_array,horizontal_kernel)


filtered_image_1d = apply_filter(filtered_image_1d_horizontal, vertical_kernel)

filtered_image_2d = apply_filter(img_array, gaussian_2d)
#ploting original and filtered images using matplotlib
plt.figure(figsize=(12,6))

#original image
plt.subplot(2,2,1)
plt.imshow(original_image,cmap='gray')
plt.title('original image')
plt.axis('off')

plt.subplot(2,2,3)
plt.imshow(filtered_image_1d_vertical, cmap='gray')
plt.title('vertical 1D filters applied')
plt.axis('off')

plt.subplot(2,2,4)
plt.imshow(filtered_image_2d, cmap='gray')
plt.title('2D filter applied')
plt.axis('off')


plt.show()
# Out:
# Horizontal_gausian kernel:
#  [[0.00285673]
#  [0.00480493]
#  [0.00773848]
#  [0.01193369]
#  [0.01762155]
#  [0.02491517]
#  [0.03373136]
#  [0.04372748]
#  [0.05427819]
#  [0.06451292]
#  [0.07342069]
#  [0.08000934]
#  [0.08348593]
#  [0.08341349]
#  [0.07980125]
#  [0.07310272]
#  [0.06412211]
#  [0.05385579]
#  [0.04331193]
#  [0.03335285]
#  [0.02459285]
#  [0.01736342]
#  [0.01173848]
#  [0.0075987 ]
#  [0.00470995]]
# verical_gausian kernel:
#  [[0.00285673]
#  [0.00480493]
#  [0.00773848]
#  [0.01193369]
#  [0.01762155]
#  [0.02491517]
#  [0.03373136]
#  [0.04372748]
#  [0.05427819]
#  [0.06451292]
#  [0.07342069]
#  [0.08000934]
#  [0.08348593]
#  [0.08341349]
#  [0.07980125]
#  [0.07310272]
#  [0.06412211]
#  [0.05385579]
#  [0.04331193]
#  [0.03335285]
#  [0.02459285]
#  [0.01736342]
#  [0.01173848]
#  [0.0075987 ]
#  [0.00470995]]

# %%
import cv2
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


def gaussian_kernel_1d_horizontal(sigma,length):
    """generate a ID horizontal gaussian kernel"""
    x = np.linspace(-length // 2, length//2, length)
    kernel_1d = np.exp(-(x**2)/(2 * sigma**2))
    return kernel_1d / np.sum(kernel_1d)


def gaussian_kernel_1d_horizontal(sigma,length):
    """generate a ID horizontal gaussian kernel"""
    x = np.linspace(-length // 2, length//2, length)
    kernel_1d = np.exp(-(x**2)/(2 * sigma**2))
    return (kernel_1d / np.sum(kernel_1d)).reshape(-1,1)

#parameters for gausian filtetr
sigma=5.0
kernel_size=25

#generate horizontaland vertical gausian kernels
horizontal_kernel = gaussian_kernel_1d_horizontal(sigma, kernel_size)
vertical_kernel = gaussian_kernel_1d_horizontal(sigma, kernel_size)

#output thekernels
print("Horizontal_gausian kernel:\n",horizontal_kernel )
print("verical_gausian kernel:\n",vertical_kernel )

def apply_filter(image, kernel):
    #determine if the kernel is horizontal or vertical
    if kernel.ndim ==1:
        #for a horizontal kernel,reshape itto (1, kernel_size)
        if kernel.shape[0] == 1:
            kernel = kernel.reshape(1,-1)
        #for a vertical kernel,reshape into a (kernel_size, 1)
        else:
            kernel = kernel.reshape(-1,1)
            
    #apply 2D convolution
    return convolve(image, kernel,mode='constant', cval=0.0)

#generate the equivalent 2D gaussian filter
gaussian_2d = np.outer(horizontal_kernel, vertical_kernel)
   

#load image
image_path='./Desktop/images/1.jpg'
original_image = Image.open(image_path).convert('L')
img_array =np.asarray(original_image)


#apply the 1D filter
filtered_image_1d_horizontal = apply_filter(img_array,horizontal_kernel)
filtered_image_1d_vertical = apply_filter(img_array,horizontal_kernel)


filtered_image_1d = apply_filter(filtered_image_1d_horizontal, vertical_kernel)

filtered_image_2d = apply_filter(img_array, gaussian_2d)
#ploting original and filtered images using matplotlib
plt.figure(figsize=(12,6))

#original image
plt.subplot(2,2,1)
plt.imshow(original_image,cmap='gray')
plt.title('original image')
plt.axis('off')

plt.subplot(2,2,3)
plt.imshow(filtered_image_1d_vertical, cmap='gray')
plt.title('vertical 1D filters applied')
plt.axis('off')

plt.subplot(2,2,4)
plt.imshow(filtered_image_2d, cmap='gray')
plt.title('2D filter applied')
plt.axis('off')


plt.show()
# Out:
# Horizontal_gausian kernel:
#  [[0.00285673]
#  [0.00480493]
#  [0.00773848]
#  [0.01193369]
#  [0.01762155]
#  [0.02491517]
#  [0.03373136]
#  [0.04372748]
#  [0.05427819]
#  [0.06451292]
#  [0.07342069]
#  [0.08000934]
#  [0.08348593]
#  [0.08341349]
#  [0.07980125]
#  [0.07310272]
#  [0.06412211]
#  [0.05385579]
#  [0.04331193]
#  [0.03335285]
#  [0.02459285]
#  [0.01736342]
#  [0.01173848]
#  [0.0075987 ]
#  [0.00470995]]
# verical_gausian kernel:
#  [[0.00285673]
#  [0.00480493]
#  [0.00773848]
#  [0.01193369]
#  [0.01762155]
#  [0.02491517]
#  [0.03373136]
#  [0.04372748]
#  [0.05427819]
#  [0.06451292]
#  [0.07342069]
#  [0.08000934]
#  [0.08348593]
#  [0.08341349]
#  [0.07980125]
#  [0.07310272]
#  [0.06412211]
#  [0.05385579]
#  [0.04331193]
#  [0.03335285]
#  [0.02459285]
#  [0.01736342]
#  [0.01173848]
#  [0.0075987 ]
#  [0.00470995]]

# %%
import numpy as np
from PIL import Image
import numpy as np
from PIL import Image

def salt_and_pepper_noise(image, amount):
    """
    :param image: A PIL Image object.
    :paramamount:propotion ofimage pixels toalter (between 0 n 1)
    :return: Image with salt and pepper noise.
    """
    output = np.array(image)
    #calthe total number of pixels
    num_pixels = output.shape[0] * output.shape[1]
    
    #amount of salt and pepper noise
    num_salt = np.ceil(amount * num_pixels* 0.5).astype(int)
    num_pepper = np.ceil(amount * num_pixels* 0.5).astype(int)
    
    #add salt noise(white pixels)
    coords = [np.random.randint(0, i-1,num_salt) for i in output.shape[:2]]
    output[coords[0], coords[1]] = 255
    
    #add pepper noise(black pixels)
    
    coords = [np.random.randint(0, i-1,num_pepper) for i in output.shape[:2]]
    output[coords[0], coords[1]] = 0
    
    image_path='./Desktop/images/1.jpg'
    original_image = Image.open(image_path).convert('L')
    
    noisy_image = salt_and_pepper_noise(original_image, 0.05)#5%
    
    plt.figure(figsize=(12,6))
    
    
    plt.subplot(1,2,1)
    plt.imshow(original_image, cmap='gray')
    plt.title('original_image')
    plt.axis('off')
